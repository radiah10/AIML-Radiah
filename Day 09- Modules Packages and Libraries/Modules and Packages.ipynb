# %%
import idrees_lib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import idrees_lib
#
# ModuleNotFoundError: No module named 'idrees_lib'

# %%
import test_project.greet as greeting

# we can't execute script files like this in notebooks
# test_project.greet

# 
greeting.hello("idrees")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import test_project.greet as greeting
#       3 # we can't execute script files like this in notebooks
#       4 # test_project.greet
#       5
#       6 #
#       7 greeting.hello("idrees")
#
# ModuleNotFoundError: No module named 'test_project.greet'

# %%
from test_project import greet

greet.evening()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from test_project import greet
#       3 greet.evening()
#
# ImportError: cannot import name 'greet' from 'test_project' (unknown location)

# %%
import SchoolManagementSystem as sms
