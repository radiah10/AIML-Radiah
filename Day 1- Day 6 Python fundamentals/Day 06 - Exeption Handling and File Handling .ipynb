# %%
try:
    x = int(input("enter a number"))
    y = 10 / x
    print("Result = ", y)
except:
    print("Something is Wrong!!!")

# %%
try:
    x = int(input("enter a number"))
    y = 10 / x
    print("Result = ", y)
    if x == 1:
        print('yaay zero!!')

# except ZeroDivisionError:
#     print("you divided with 0, you dummy!!!")
except TypeError:
    print("you divided a number with a alphabet or string, you dummy!!!")
except Exception as e:
    print("You don't know how to code. go train yourself first!!", e)

# %%
try:
    file = open("idrees.txt", "r") 
except Exception as e:
    print("Something is wrong.", e)
# Out:
# Something is wrong. [Errno 2] No such file or directory: 'idrees.txt'

# %%
# CREATE - a file
file = open("idrees.txt","w") # write - "w"

# %%
# OPEN - a file
file = open("idrees.txt", "r")  # read - "r"

# %%
# WRITE - on a file
# open in write mode
file = open("idrees.txt", "w+") # open in write + read mode

file.write("Idrees is an awesome TEACHERRRRRRR\n")
# Out:
# 35

# %%
file.write("Idrees is an awesome TEACHERRRRRRR\n")
# Out:
# 35

# %%
# APPEND - on a file

file = open("idrees.txt", "a") # add things to the file instead of replace

# %%
file = open("idrees.txt", "r+")

# %%
file.read()
# Out:
# 'Idrees is an awesome TEACHERRRRRRR\nIdrees is an awesome TEACHERRRRRRR\n'

# %%
with open("idrees.txt", "w+") as f:
    f.write("Idrees is awesome\n")
    f.write("idrees wins all the battles he fights\n")

# %%
with open("idrees.txt", "r") as f:
    content = f.read()
    print(content)
# Out:
# Idrees is awesome
# idrees wins all the battles he fights

# %%
with open("idrees.csv", "w+") as f:
    f.write("name, age, subject\n")
    f.write("idrees, 30, AIML\n")

# %%
with open("idrees.csv", "a") as f:
    f.write("Naufal, 29, CSE\n")

# %%
path = r"/workspaces/AIML-Nexperts-Batch5/data/idrees.csv"

with open(path, "r") as f:
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 path = r"/workspaces/AIML-Nexperts-Batch5/data/idrees.csv"
# ----> 3 with open(path, "r") as f:
#       4     print(f.read())
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspaces/AIML-Nexperts-Batch5/data/idrees.csv'

# %%
r" idreees hello \n hello" # r - raw string
# f - formatted strings
# Out:
# ' idreees hello \\n hello'

# %%
" idreees hello \n hello"
# Out:
# ' idreees hello \n hello'

# %%
import os

os.remove("idrees.txt")
