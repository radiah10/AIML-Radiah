# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv("employee.csv")
display(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("employee.csv")
#       2 display(df)
#
# NameError: name 'pd' is not defined

# %%
# acessing columns in the dataframe
# access columns by --- Name
df['Name']
df.Name # only one column


columns = ["Name","Salary",	"Experience"]
df[columns]

# subset of dataframe
df_salary = df[["Salary",	"Experience"]]
display(df_salary)

#df["Name","Salary"] # will not work
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # acessing columns in the dataframe
#       2 # access columns by --- Name
# ----> 3 df['Name']
#       4 df.Name # only one column
#       7 columns = ["Name","Salary",	"Experience"]
#
# NameError: name 'df' is not defined

# %%
display(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 display(df)
#
# NameError: name 'df' is not defined

# %%
df.iloc[0] # first row as a series object

df.iloc[-1] # last row

df.iloc[1:3] # rows from 1 upto 3

df.iloc[1:4:2] # in steps of 2

# ---- indexing works

df.iloc[:4, 1:3] #first 4 rows, 

df.iloc[[0,2,3], [0,2,3]] # you can access the rows, columns by number, but
# if out of index, error will be thrown
# errors are not thrown if you are accessing using slices
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.iloc[0] # first row as a series object
#       3 df.iloc[-1] # last row
#       5 df.iloc[1:3] # rows from 1 upto 3
#
# NameError: name 'df' is not defined

# %%
# i want the data of the last two entries, for department and experience
df.iloc[-2:,[1,3]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # i want the data of the last two entries, for department and experience
# ----> 2 df.iloc[-2:,[1,3]]
#
# NameError: name 'df' is not defined

# %%
# 
ind = ['a','b','c','d','e']
df = pd.read_csv("employee.csv")
df['index'] = ind

df = df.set_index('index')
display(df)
# -----
df.index = ['a','b','c','d','e']
display(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 #
#       2 ind = ['a','b','c','d','e']
# ----> 3 df = pd.read_csv("employee.csv")
#       4 df['index'] = ind
#       6 df = df.set_index('index')
#
# NameError: name 'pd' is not defined

# %%
df.loc[0] # row
df.loc[0:3] # slice of rows

# df.loc[0:3, 0:3] # throws an error

df.loc[0:3, ['Department', 'Experience']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.loc[0] # row
#       2 df.loc[0:3] # slice of rows
#       4 # df.loc[0:3, 0:3] # throws an error
#
# NameError: name 'df' is not defined

# %%
df.loc['a':'d', 'Department':'Experience': 2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.loc['a':'d', 'Department':'Experience': 2]
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("employee.csv")

df.index = ("a","b","c","d","e")
 
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_csv("employee.csv")
#       3 df.index = ("a","b","c","d","e")
#       5 df
#
# NameError: name 'pd' is not defined

# %%
df.index
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.index
#       2 df.columns
#
# NameError: name 'df' is not defined

# %%
# adding a column
# access a column that does not exist
df['email'] = ['alice@gmail.com','Bob@gmail.com','charlie@gmail.com','diana@gmail.com','eve@gmail.com']
df

# modify a column
list(df['Department']) 

df['Department'] = ['Engineering', 'Marketing', 'Physics', 'HR', 'Marketing']

# use modify all elements of a column --- in one go 
df.Salary = df.Salary/1000 # Scaling operation
# took the column and scaled it down

df.Experience = df.Experience +1
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # adding a column
#       2 # access a column that does not exist
# ----> 3 df['email'] = ['alice@gmail.com','Bob@gmail.com','charlie@gmail.com','diana@gmail.com','eve@gmail.com']
#       4 df
#       6 # modify a column
#
# NameError: name 'df' is not defined

# %%
# modfying a value
# df['Department']['d'] = 'Crime Analytics'

df.loc['d','Department'] = 'Crime Analytics'

df.iloc[3, 1] = 'Linguistics'
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 # modfying a value
#       2 # df['Department']['d'] = 'Crime Analytics'
# ----> 4 df.loc['d','Department'] = 'Crime Analytics'
#       6 df.iloc[3, 1] = 'Linguistics'
#       7 df
#
# NameError: name 'df' is not defined
