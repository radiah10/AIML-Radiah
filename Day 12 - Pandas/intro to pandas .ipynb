# %%
#pip install pandas

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
maths = pd.Series([20, 30, 40], dtype = 'int8', name = 'math')
type(maths) # pandas.Series

print(maths)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 maths = pd.Series([20, 30, 40], dtype = 'int8', name = 'math')
#       2 type(maths) # pandas.Series
#       4 print(maths)
#
# NameError: name 'pd' is not defined

# %%
english = pd.Series([20, 30, 40])
python = pd.Series([20, 55, 40])
science = pd.Series([20, 99, 40])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 english = pd.Series([20, 30, 40])
#       2 python = pd.Series([20, 55, 40])
#       3 science = pd.Series([20, 99, 40])
#
# NameError: name 'pd' is not defined

# %%
pd.concat([maths,english, python, science]) # series object
df = pd.concat([maths,english, python, science], axis = 1)

type(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.concat([maths,english, python, science]) # series object
#       2 df = pd.concat([maths,english, python, science], axis = 1)
#       4 type(df)
#
# NameError: name 'pd' is not defined

# %%
# dataframe from dictionary of Lists  --- each list has to be of same size
data = {
    "Students": ["Nomie", "Idrees", "Radia"],
    "Maths": [85, 95, 90],
    "English": [75, 85 , 80],
}

df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 8
#       1 # dataframe from dictionary of Lists  --- each list has to be of same size
#       2 data = {
#       3     "Students": ["Nomie", "Idrees", "Radia"],
#       4     "Maths": [85, 95, 90],
#       5     "English": [75, 85 , 80],
#       6 }
# ----> 8 df = pd.DataFrame(data)
#       9 df
#
# NameError: name 'pd' is not defined

# %%
# dataframe from List of Dictionaries --- each dictionary can be of different size
# we can miss elements --- those elements will appear as NaN values

data = [
    {'Name': 'Alice', 'Age': 25, 'City': 'New York'},
    {'Name': 'Bob', 'Age': 30, 'City': 'London'},
    {'Name': 'Charlie', 'Age': 35}
]

df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       1 # dataframe from List of Dictionaries --- each dictionary can be of different size
#       2 # we can miss elements --- those elements will appear as NaN values
#       4 data = [
#       5     {'Name': 'Alice', 'Age': 25, 'City': 'New York'},
#       6     {'Name': 'Bob', 'Age': 30, 'City': 'London'},
#       7     {'Name': 'Charlie', 'Age': 35}
#       8 ]
# ---> 10 df = pd.DataFrame(data)
#      11 df
#
# NameError: name 'pd' is not defined

# %%
# dataframe from 2D arrays
data = [
    ['Alice', 25, 'New York'],
    ['Bob', 30, 'London'],
    ['Charlie', 35, 'Paris']
]

# We must explicitly define columns here
df = pd.DataFrame(data, columns=['Name', 'Age', 'City'], )
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       2 data = [
#       3     ['Alice', 25, 'New York'],
#       4     ['Bob', 30, 'London'],
#       5     ['Charlie', 35, 'Paris']
#       6 ]
#       8 # We must explicitly define columns here
# ----> 9 df = pd.DataFrame(data, columns=['Name', 'Age', 'City'], )
#      10 print(df)
#
# NameError: name 'pd' is not defined

# %%
# DataFrames from Files

# From a CSV file
# df_csv = pd.read_csv('my_data.csv')

# From an Excel file
# df_excel = pd.read_excel('my_data.xlsx')

# From a JSON file or API response
# df_json = pd.read_json('my_data.json')

# %%
# Let's create a sample CSV file first, then read it
sample_data = """Name,Department,Salary,Experience
Alice,Engineering,75000,3
Bob,Marketing,65000,5
Charlie,Engineering,80000,7
Diana,HR,60000,2
Eve,Marketing,70000,4"""

with open("employee.csv", 'w') as f:
    f.write(sample_data)

# %%
df = pd.read_csv("employee.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_csv("employee.csv")
#       2 df
#
# NameError: name 'pd' is not defined

# %%
# Dataframe for the Previou Scenario Exercise

import numpy as np
np.random.seed(42)
 
#2.
results = np.random.randint(0,101, (10,3))
print("--- Results ---")
print(results)

df_results = pd.DataFrame(results, columns = ["maths", "english","science"])

df_results.to_csv("student_marks.csv", index = False) # it excludes the index
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Dataframe for the Previou Scenario Exercise
# ----> 3 import numpy as np
#       4 np.random.seed(42)
#       6 #2.
#
# ModuleNotFoundError: No module named 'numpy'
